# %% [markdown]
# # Part 1) Load the data and make a datetime index.

# %% [markdown]
# You must first load the data and create a datetime index.
#
# Convert the date column to datetime dtype.
# Set the date column as the index.
# Filter out only the required data:
# Keep only data from the year 2000 or later.
# Keep only the following features:
# precipitation
# mean_temp
# min_temp
# max_temp
# snow_depth
# Impute any missing values.
# Think about each feature and what imputation method makes sense. You may not be able to use the same method for every feature!

# %%
import datetime as dt

# %%
## You can obtain the current date and time with .now()
now = dt.datetime.now()
now
# Out:
# datetime.datetime(2023, 9, 3, 19, 15, 26, 347423)

# %%
import pandas as pd
url="https://docs.google.com/spreadsheets/d/e/2PACX-1vT_jChgNsQbHbg4TGepzIqk8XC9DTIKmyyxb1upo5cfZCgbfIUQc2ZC0YMzuU5uApP140Ob49KBjdqh/pub?gid=1198589591&single=true&output=csv"
df = pd.read_csv(url)
df.info()
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15341 entries, 0 to 15340
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              15341 non-null  int64
#  1   cloud_cover       14938 non-null  float64
#  2   sunshine          14957 non-null  float64
#  3   global_radiation  14939 non-null  float64
#  4   max_temp          14951 non-null  float64
#  5   mean_temp         14922 non-null  float64
#  6   min_temp          14955 non-null  float64
#  7   precipitation     14951 non-null  float64
#  8   pressure          14953 non-null  float64
#  9   snow_depth        13589 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 1.2 MB
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# ...

# %%
df['date'] = df['date'].astype(str)

# %%
#Add a datetime column based on the string in the "date" column
df['datetime'] = pd.to_datetime(df['date'])
df.info()
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15341 entries, 0 to 15340
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              15341 non-null  object
#  1   cloud_cover       14938 non-null  float64
#  2   sunshine          14957 non-null  float64
#  3   global_radiation  14939 non-null  float64
#  4   max_temp          14951 non-null  float64
#  5   mean_temp         14922 non-null  float64
#  6   min_temp          14955 non-null  float64
#  7   precipitation     14951 non-null  float64
#  8   pressure          14953 non-null  float64
#  9   snow_depth        13589 non-null  float64
#  10  datetime          15341 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(9), object(1)
# memory usage: 1.3+ MB
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# ...

# %% [markdown]
# # Setting a Datetime Index

# %%
df = df.set_index('datetime')
df
# Out:
#                 date  cloud_cover  sunshine  global_radiation  max_temp  \
# datetime
# 1979-01-01  19790101          2.0       7.0              52.0       2.3
# 1979-01-02  19790102          6.0       1.7              27.0       1.6
# 1979-01-03  19790103          5.0       0.0              13.0       1.3
# 1979-01-04  19790104          8.0       0.0              13.0      -0.3
# 1979-01-05  19790105          6.0       2.0              29.0       5.6
# ...              ...          ...       ...               ...       ...
# 2020-12-27  20201227          1.0       0.9              32.0       7.5
# 2020-12-28  20201228          7.0       3.7              38.0       3.6
# 2020-12-29  20201229          7.0       0.0              21.0       4.1
# 2020-12-30  20201230          6.0       0.4              22.0       5.6
# 2020-12-31  20201231          7.0       1.3              34.0       1.5
#
#             mean_temp  min_temp  precipitation  pressure  snow_depth
# datetime
# ...

# %%
df.index
# Out:
# DatetimeIndex(['1979-01-01', '1979-01-02', '1979-01-03', '1979-01-04',
#                '1979-01-05', '1979-01-06', '1979-01-07', '1979-01-08',
#                '1979-01-09', '1979-01-10',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', name='datetime', length=15341, freq=None)

# %% [markdown]
# Filter out only the required data:
# Keep only data from the year 2000 or later.
# Keep only the following features:
# precipitation
# mean_temp
# min_temp
# max_temp
# snow_depth

# %%
df=df.loc['2000':]
df.head()
# Out:
#                 date  cloud_cover  sunshine  global_radiation  max_temp  \
# datetime
# 2000-01-01  20000101          7.0       0.4              18.0      10.8
# 2000-01-02  20000102          7.0       0.7              20.0      11.5
# 2000-01-03  20000103          8.0       0.0              13.0       9.5
# 2000-01-04  20000104          5.0       2.9              34.0      11.0
# 2000-01-05  20000105          5.0       1.3              25.0      10.8
#
#             mean_temp  min_temp  precipitation  pressure  snow_depth
# datetime
# 2000-01-01        7.0       4.9            0.0  102450.0         0.0
# 2000-01-02        7.9       5.0            0.2  102530.0         0.0
# 2000-01-03        9.4       7.2            6.0  101860.0         0.0
# 2000-01-04        7.0       4.4            0.2  101480.0         0.0
# 2000-01-05        6.4       1.9            0.8  101420.0         0.0

# %%
df=df[['mean_temp','min_temp','max_temp','snow_depth','precipitation']]
df.head()
# Out:
#             mean_temp  min_temp  max_temp  snow_depth  precipitation
# datetime
# 2000-01-01        7.0       4.9      10.8         0.0            0.0
# 2000-01-02        7.9       5.0      11.5         0.0            0.2
# 2000-01-03        9.4       7.2       9.5         0.0            6.0
# 2000-01-04        7.0       4.4      11.0         0.0            0.2
# 2000-01-05        6.4       1.9      10.8         0.0            0.8

# %% [markdown]
# Impute any missing values.
# Think about each feature and what imputation method makes sense. You may not be able to use the same method for every feature!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7671 entries, 2000-01-01 to 2020-12-31
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mean_temp      7252 non-null   float64
#  1   min_temp       7285 non-null   float64
#  2   max_temp       7281 non-null   float64
#  3   snow_depth     5919 non-null   float64
#  4   precipitation  7281 non-null   float64
# dtypes: float64(5)
# memory usage: 359.6 KB

# %%
ts_D = df.asfreq("D")
ts_D.head(10)
# Out:
#             mean_temp  min_temp  max_temp  snow_depth  precipitation
# datetime
# 2000-01-01        7.0       4.9      10.8         0.0            0.0
# 2000-01-02        7.9       5.0      11.5         0.0            0.2
# 2000-01-03        9.4       7.2       9.5         0.0            6.0
# 2000-01-04        7.0       4.4      11.0         0.0            0.2
# 2000-01-05        6.4       1.9      10.8         0.0            0.8
# 2000-01-06        8.9       7.0      11.0         0.0            0.0
# 2000-01-07        7.2       3.4       9.2         0.0            2.0
# 2000-01-08        7.4       5.7       7.2         0.0            0.0
# 2000-01-09        3.2      -0.7       7.8         0.0            0.2
# 2000-01-10        2.2      -3.3      10.2         0.0            0.0

# %%
ts=df['mean_temp'].copy()
ts
# Out:
# datetime
# 2000-01-01    7.0
# 2000-01-02    7.9
# 2000-01-03    9.4
# 2000-01-04    7.0
# 2000-01-05    6.4
#              ...
# 2020-12-27    7.5
# 2020-12-28    1.1
# 2020-12-29    2.6
# 2020-12-30    2.7
# 2020-12-31   -0.8
# Name: mean_temp, Length: 7671, dtype: float64

# %%
day_of_week = ts.index.day_name()
day_of_week.value_counts()
# Out:
# Saturday     1096
# Sunday       1096
# Monday       1096
# Tuesday      1096
# Wednesday    1096
# Thursday     1096
# Friday       1095
# Name: datetime, dtype: int64

# %%
ts_D = ts.asfreq("D")
ts_D.head(20)
# Out:
# datetime
# 2000-01-01    7.0
# 2000-01-02    7.9
# 2000-01-03    9.4
# 2000-01-04    7.0
# 2000-01-05    6.4
# 2000-01-06    8.9
# 2000-01-07    7.2
# 2000-01-08    7.4
# 2000-01-09    3.2
# 2000-01-10    2.2
# 2000-01-11    5.4
# 2000-01-12    8.0
# 2000-01-13    3.8
# 2000-01-14    2.9
# 2000-01-15    4.6
# 2000-01-16    4.7
# 2000-01-17    NaN
# 2000-01-18    4.8
# 2000-01-19    5.4
# 2000-01-20    NaN
# Freq: D, Name: mean_temp, dtype: float64

# %%
ts_D.isna().sum()
# Out:
# 419

# %%
##  Plotting the missing data
ax = ts_D.plot(style='o-', title='Resampled TS with Null Values',)
##  Annotating region with null values to impute
ax.axvspan('2000-01-01','2020-12-31',color='#f7797d', alpha=0.5, zorder=0, label='Missing Data')
ax.legend();

# %%
ts_interp = ts_D.interpolate()
print(ts_interp)
ax = ts_interp.plot(style='o-', color='slategray', lw=2,title='Interpolated');
##  annotating start and end values used by interpolate
ax.axvline('2000-01-01', color='slategray',ls=':',lw=3)
ax.axvline('2020-12-31', color='slategray',ls=':',lw=3)
ax.axvspan('2000-01-01','2020-12-31', color='#f7797d', alpha=0.5, zorder=0, label='Missing Data')
ax.legend();
# Out:
# datetime
# 2000-01-01    7.0
# 2000-01-02    7.9
# 2000-01-03    9.4
# 2000-01-04    7.0
# 2000-01-05    6.4
#              ...
# 2020-12-27    7.5
# 2020-12-28    1.1
# 2020-12-29    2.6
# 2020-12-30    2.7
# 2020-12-31   -0.8
# Freq: D, Name: mean_temp, Length: 7671, dtype: float64

# %%
ts_D.head(25)
# Out:
# datetime
# 2000-01-01    7.0
# 2000-01-02    7.9
# 2000-01-03    9.4
# 2000-01-04    7.0
# 2000-01-05    6.4
# 2000-01-06    8.9
# 2000-01-07    7.2
# 2000-01-08    7.4
# 2000-01-09    3.2
# 2000-01-10    2.2
# 2000-01-11    5.4
# 2000-01-12    8.0
# 2000-01-13    3.8
# 2000-01-14    2.9
# 2000-01-15    4.6
# 2000-01-16    4.7
# 2000-01-17    4.7
# 2000-01-18    4.8
# 2000-01-19    5.4
# 2000-01-20    5.4
# 2000-01-21    5.0
# 2000-01-22    5.2
# 2000-01-23    4.0
# 2000-01-24    3.1
# 2000-01-25    0.5
# Freq: D, Name: mean_temp, dtype: float64

# %%
ts_D.isna().sum()
# Out:
# 0

# %%
##  saving 1 week of values to use for demonstration
example = ts_D.loc['2000-01-01':'2000-01-21']
example
# Out:
# datetime
# 2000-01-01    7.0
# 2000-01-02    7.9
# 2000-01-03    9.4
# 2000-01-04    7.0
# 2000-01-05    6.4
# 2000-01-06    8.9
# 2000-01-07    7.2
# 2000-01-08    7.4
# 2000-01-09    3.2
# 2000-01-10    2.2
# 2000-01-11    5.4
# 2000-01-12    8.0
# 2000-01-13    3.8
# 2000-01-14    2.9
# 2000-01-15    4.6
# 2000-01-16    4.7
# 2000-01-17    4.7
# 2000-01-18    4.8
# 2000-01-19    5.4
# 2000-01-20    5.4
# 2000-01-21    5.0
# Freq: D, Name: mean_temp, dtype: float64

# %%
##  Plotting the missing data
ax = example.plot(style='o-', title='Resampled TS with Null Values',)
##  Annotating region with null values to impute
ax.axvspan('2000-01-16','2000-01-21',color='#f7797d', alpha=0.5, zorder=0, label='Missing Data')
ax.legend();

# %%
ts1=df['mean_temp'].copy()
ts1
# Out:
# datetime
# 2000-01-01    7.0
# 2000-01-02    7.9
# 2000-01-03    9.4
# 2000-01-04    7.0
# 2000-01-05    6.4
#              ...
# 2020-12-27    7.5
# 2020-12-28    1.1
# 2020-12-29    2.6
# 2020-12-30    2.7
# 2020-12-31   -0.8
# Name: mean_temp, Length: 7671, dtype: float64

# %%
ts_D1= ts.asfreq("D")
ts_D1.head(20)
# Out:
# datetime
# 2000-01-01    4.9
# 2000-01-02    5.0
# 2000-01-03    7.2
# 2000-01-04    4.4
# 2000-01-05    1.9
# 2000-01-06    7.0
# 2000-01-07    3.4
# 2000-01-08    5.7
# 2000-01-09   -0.7
# 2000-01-10   -3.3
# 2000-01-11    0.6
# 2000-01-12    7.8
# 2000-01-13    2.7
# 2000-01-14   -0.5
# 2000-01-15    2.6
# 2000-01-16    2.2
# 2000-01-17    NaN
# 2000-01-18    1.2
# 2000-01-19    3.6
# 2000-01-20    NaN
# Freq: D, Name: min_temp, dtype: float64

# %%
ts_D1.isna().sum()
# Out:
# 386

# %%
##  Plotting the missing data
ax = ts_D1.plot(style='o-', title='Resampled TS with Null Values',)
##  Annotating region with null values to impute
ax.axvspan('2000-01-01','2020-12-31',color='#f7797d', alpha=0.5, zorder=0, label='Missing Data')
ax.legend();

# %%
ts_ffill1 = ts_D1.fillna(method='ffill')
print(ts_ffill1)
ax = ts_ffill1.plot(style='o-',title='Forward-Filled', color='forestgreen');
ax.axvline('2000-01-01',color='forestgreen',lw=3, ls=':')
ax.axvspan('2000-01-01','2020-12-31', color='#f7797d', alpha=0.5, zorder=0, label='Missing Data')
ax.legend();
# Out:
# datetime
# 2000-01-01    4.9
# 2000-01-02    5.0
# 2000-01-03    7.2
# 2000-01-04    4.4
# 2000-01-05    1.9
#              ...
# 2020-12-27    7.6
# 2020-12-28   -1.3
# 2020-12-29    1.1
# 2020-12-30   -0.1
# 2020-12-31   -3.1
# Freq: D, Name: min_temp, Length: 7671, dtype: float64

# %%
ts_D1.isna().sum()
# Out:
# 0

# %%
ts2=df['max_temp'].copy()
ts2
# Out:
# datetime
# 2000-01-01    10.8
# 2000-01-02    11.5
# 2000-01-03     9.5
# 2000-01-04    11.0
# 2000-01-05    10.8
#               ...
# 2020-12-27     7.5
# 2020-12-28     3.6
# 2020-12-29     4.1
# 2020-12-30     5.6
# 2020-12-31     1.5
# Name: max_temp, Length: 7671, dtype: float64

# %%
ts_D2 = ts.asfreq("D")
ts_D2.head(20)
# Out:
# datetime
# 2000-01-01    4.9
# 2000-01-02    5.0
# 2000-01-03    7.2
# 2000-01-04    4.4
# 2000-01-05    1.9
# 2000-01-06    7.0
# 2000-01-07    3.4
# 2000-01-08    5.7
# 2000-01-09   -0.7
# 2000-01-10   -3.3
# 2000-01-11    0.6
# 2000-01-12    7.8
# 2000-01-13    2.7
# 2000-01-14   -0.5
# 2000-01-15    2.6
# 2000-01-16    2.2
# 2000-01-17    NaN
# 2000-01-18    1.2
# 2000-01-19    3.6
# 2000-01-20    NaN
# Freq: D, Name: min_temp, dtype: float64

# %%
ts_D2.isna().sum()
# Out:
# 386

# %%
##  Plotting the missing data
ax = ts_D2.plot(style='o-', title='Resampled TS with Null Values',)
##  Annotating region with null values to impute
ax.axvspan('2000-01-01','2020-12-31',color='#f7797d', alpha=0.5, zorder=0, label='Missing Data')
ax.legend();

# %%
ts_ffill2 = ts_D2.fillna(method='bfill')
print(ts_ffill2)
ax = ts_ffill2.plot(style='o-',title='Forward-Filled', color='forestgreen');
ax.axvline('2000-01-01',color='forestgreen',lw=3, ls=':')
ax.axvspan('2000-01-01','2020-12-31', color='#f7797d', alpha=0.5, zorder=0, label='Missing Data')
ax.legend();
# Out:
# datetime
# 2000-01-01    4.9
# 2000-01-02    5.0
# 2000-01-03    7.2
# 2000-01-04    4.4
# 2000-01-05    1.9
#              ...
# 2020-12-27    7.6
# 2020-12-28   -1.3
# 2020-12-29    1.1
# 2020-12-30   -0.1
# 2020-12-31   -3.1
# Freq: D, Name: min_temp, Length: 7671, dtype: float64

# %%
ts_D2.isna().sum().sum()
# Out:
# 0

# %%
ts3=df['max_temp'].copy()
ts2
# Out:
# datetime
# 2000-01-01    10.8
# 2000-01-02    11.5
# 2000-01-03     9.5
# 2000-01-04    11.0
# 2000-01-05    10.8
#               ...
# 2020-12-27     7.5
# 2020-12-28     3.6
# 2020-12-29     4.1
# 2020-12-30     5.6
# 2020-12-31     1.5
# Name: max_temp, Length: 7671, dtype: float64

# %%
ts_D3 = ts3.asfreq("D")
ts_D3.head(20)
# Out:
# datetime
# 2000-01-01    10.8
# 2000-01-02    11.5
# 2000-01-03     9.5
# 2000-01-04    11.0
# 2000-01-05    10.8
# 2000-01-06    11.0
# 2000-01-07     9.2
# 2000-01-08     7.2
# 2000-01-09     7.8
# 2000-01-10    10.2
# 2000-01-11     8.2
# 2000-01-12     5.0
# 2000-01-13     6.3
# 2000-01-14     6.7
# 2000-01-15     7.2
# 2000-01-16     8.6
# 2000-01-17     NaN
# 2000-01-18     7.3
# 2000-01-19     5.3
# 2000-01-20     NaN
# Freq: D, Name: max_temp, dtype: float64

# %%
ts_ffill3 = ts_D3.fillna(method='ffill')
print(ts_ffill3)
ax = ts_ffill3.plot(style='o-',title='Forward-Filled', color='forestgreen');
ax.axvline('2000-01-01',color='forestgreen',lw=3, ls=':')
ax.axvspan('2000-01-01','2020-12-31', color='#f7797d', alpha=0.5, zorder=0, label='Missing Data')
ax.legend();
# Out:
# datetime
# 2000-01-01    10.8
# 2000-01-02    11.5
# 2000-01-03     9.5
# 2000-01-04    11.0
# 2000-01-05    10.8
#               ...
# 2020-12-27     7.5
# 2020-12-28     3.6
# 2020-12-29     4.1
# 2020-12-30     5.6
# 2020-12-31     1.5
# Freq: D, Name: max_temp, Length: 7671, dtype: float64

# %%
ts_D3.isna().sum().sum()
# Out:
# 0

# %%
ts4=df['snow_depth'].copy()
ts4
# Out:
# datetime
# 2000-01-01    0.0
# 2000-01-02    0.0
# 2000-01-03    0.0
# 2000-01-04    0.0
# 2000-01-05    0.0
#              ...
# 2020-12-27    NaN
# 2020-12-28    NaN
# 2020-12-29    NaN
# 2020-12-30    NaN
# 2020-12-31    NaN
# Name: snow_depth, Length: 7671, dtype: float64

# %%
ts_interp = ts4.interpolate()
print(ts_interp)
ax = ts_interp.plot(style='o-', color='slategray', lw=2,title='Interpolated');
##  annotating start and end values used by interpolate
ax.axvline('2000-01-01', color='slategray',ls=':',lw=3)
ax.axvline('2020-12-31', color='slategray',ls=':',lw=3)
ax.axvspan('2000-01-01','2020-12-31', color='#f7797d', alpha=0.5, zorder=0, label='Missing Data')
ax.legend();
# Out:
# datetime
# 2000-01-01    0.0
# 2000-01-02    0.0
# 2000-01-03    0.0
# 2000-01-04    0.0
# 2000-01-05    0.0
#              ...
# 2020-12-27    0.0
# 2020-12-28    0.0
# 2020-12-29    0.0
# 2020-12-30    0.0
# 2020-12-31    0.0
# Name: snow_depth, Length: 7671, dtype: float64

# %%
ts4.isna().sum()
# Out:
# 0

# %% [markdown]
# # Part 2) Answer the Questions with Visualizations (Using the Correct Frequency)

# %% [markdown]
# ### Q1: What month had the most precipitation between 2000 through 2010?

# %% [markdown]
# - Resample the data as Monthly frequency.

# %%
ts_M= df['precipitation'].copy()

# %%
ts_MS = ts_M.asfreq("MS")
ts_MS.name = "asfreq"
ts_MS.head()
# Out:
# datetime
# 2000-01-01    0.0
# 2000-02-01    9.8
# 2000-03-01    0.2
# 2000-04-01    0.6
# 2000-05-01    0.0
# Freq: MS, Name: asfreq, dtype: float64

# %% [markdown]
# - Find the date and corresponding value for the max precipitation.

# %%
ts_max= ts_M.resample("MS").max()
ts_max.name= 'Resampled'
ts_max.head()
# Out:
# datetime
# 2000-01-01     6.0
# 2000-02-01    16.8
# 2000-03-01     7.2
# 2000-04-01    17.2
# 2000-05-01    19.0
# Freq: MS, Name: Resampled, dtype: float64

# %% [markdown]
# Plot the feature and time period that corresponds to the question.
# Make sure to meet the "Visualization Requirements" below!
# Use a combination of pandas, matplotlib tick formatters, tick locators, and the fig.autofmt_xdate method to:
# Create a wide figure (e.g. figsize=(12,3))
# With the title "Precipitation for 2000-2010"
# With a ylabel of "Inches"
# Customize the major xaxis ticks to:
# Have major xaxis ticks every 1 year.
# Use 4-digit years for the labels
# Rotate the major ticks' labels 90 degrees.
# Customize the minor xaxis ticks to:
# Have minor xaxis ticks every 3 months
# Do not label the minor ticks.

# %%
ts_M=df['precipitation'].copy()

# %%
ts=ts_M.loc['2000':'2010']
ts.head()
# Out:
# datetime
# 2000-01-01    0.0
# 2000-01-02    0.2
# 2000-01-03    6.0
# 2000-01-04    0.2
# 2000-01-05    0.8
# Name: precipitation, dtype: float64

# %%
ts_max=ts.max()
ts_max
# Out:
# 36.6

# %%
ts_MS = ts.asfreq("MS")
ts_MS.name = "asfreq"
ts_MS.head()
# Out:
# datetime
# 2000-01-01    0.0
# 2000-02-01    9.8
# 2000-03-01    0.2
# 2000-04-01    0.6
# 2000-05-01    0.0
# Freq: MS, Name: asfreq, dtype: float64

# %%
#  plot the time series with pandas
## we've done enough customization that it makes sense to bundle this in a function
#import tick customization tools
import matplotlib.ticker as mticks
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
def plot_dates(ts_MS,figsize=(12,3),xtick_fontsize='small', xtick_fontweight='bold',
               title='Precipitation for 2000-2010'):## Make the fig and axis first
    # plot the time series with pandas
    if title is None:
        title = ts.name
    fig, ax = plt.subplots(figsize=figsize)
    ts.plot(ax=ax,title=title);
    ax.set_ylabel("inches")
    ## creating our tick locators and formatters
    ## for minor month ticks
    # create the locator to place ticks every 3 months.
    loc_3months = mdates.MonthLocator(interval=3)
    fmt_months = mdates.DateFormatter("%b")
    ## for major year ticks
    loc_year = mdates.YearLocator()
    fmt_year = mdates.DateFormatter("%Y")
    format_b = "%B %d"
    now.strftime(format_b)
    ax.axvline(ts_max, color='k', linestyle='-',label='%B %d')
    
    ## Change the font of the major ticks to stand out
    ax.set_xticks(ax.get_xticks())
    ax.set_xticklabels(ax.get_xticklabels(), 
                       fontsize=xtick_fontsize, 
                       fontweight=xtick_fontweight) 
    
    ## customize minor ticks
    ax.xaxis.set_minor_locator(loc_3months)
    ax.xaxis.set_minor_formatter(fmt_months)
    ## customize major ticks
    ax.xaxis.set_major_locator(loc_year)
    ax.xaxis.set_major_formatter(fmt_year)
    #ax.axvline('01-04-2013',color='forestgreen',lw=3, ls=':')
    ## Making major/minor gridlines visually distinct
    ax.grid(which='minor',axis='x',ls=":")
    ax.grid(which='major',axis='x',color='k')
    ## rotate the dates
    fig.autofmt_xdate(which='major',rotation=90,ha='center')
    return fig,ax
plot_dates(ts_MS);

# %% [markdown]
# ## Q2: Which year between 2000-2020 had the coolest average temperature?

# %% [markdown]
# Resample the data as Yearly frequency.
#
# Plot the feature and time period that corresponds to the question.
# Make sure to meet the "Visualization Requirements" below!
# Determine the date and value for the lowest mean temp.
# Add a vertical line at this date with a label that says the date (using date format: "2000") and the lowest mean temperature value.

# %%
df.head()
# Out:
#             mean_temp  min_temp  max_temp  snow_depth  precipitation
# datetime
# 2000-01-01        7.0       4.9      10.8         0.0            0.0
# 2000-01-02        7.9       5.0      11.5         0.0            0.2
# 2000-01-03        9.4       7.2       9.5         0.0            6.0
# 2000-01-04        7.0       4.4      11.0         0.0            0.2
# 2000-01-05        6.4       1.9      10.8         0.0            0.8

# %%
ts=df.loc['2000':'2020']
ts.head()
# Out:
#             mean_temp  min_temp  max_temp  snow_depth  precipitation
# datetime
# 2000-01-01        7.0       4.9      10.8         0.0            0.0
# 2000-01-02        7.9       5.0      11.5         0.0            0.2
# 2000-01-03        9.4       7.2       9.5         0.0            6.0
# 2000-01-04        7.0       4.4      11.0         0.0            0.2
# 2000-01-05        6.4       1.9      10.8         0.0            0.8

# %%
ts_min=ts['mean_temp']

# %%
ts_f= ts_min.asfreq("Y")
ts_f.name = "asfreq"
ts_f.head()
# Out:
# datetime
# 2000-12-31     2.8
# 2001-12-31     1.0
# 2002-12-31     7.3
# 2003-12-31     3.3
# 2004-12-31    10.6
# Freq: A-DEC, Name: asfreq, dtype: float64

# %%
min_date = ts['mean_temp'].idxmin()
min_date
print(f"the year with minimum temperature of year 2000:2020 is {min_date}")
# Out:
# the year with minimum temperature of year 2000:2020 is 2010-12-20 00:00:00

# %%
ts.loc[min_date]
# Out:
# mean_temp       -4.1
# min_temp        -9.4
# max_temp         1.8
# snow_depth       5.0
# precipitation    0.0
# Name: 2010-12-20 00:00:00, dtype: float64

# %%
str_date = ts.loc[min_date,'min_temp']
str_date
print(f"the coolest temperature is {-9.4}")
# Out:
# the coolest temperature is -9.4

# %%
ts_p=ts['precipitation'].idxmax()
ts_p
# Out:
# Timestamp('2015-08-26 00:00:00')

# %%
ts.loc[ts_p]
# Out:
# mean_temp        17.0
# min_temp         14.1
# max_temp         19.6
# snow_depth        0.0
# precipitation    51.6
# Name: 2015-08-26 00:00:00, dtype: float64

# %%
max_prec=ts.loc[ts_p,'precipitation']
max_prec
# Out:
# 51.6

# %%
#  plot the time series with pandas
## we've done enough customization that it makes sense to bundle this in a function
#import tick customization tools
import matplotlib.ticker as mticks
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
def plot_dates(ts_f,figsize=(12,3),xtick_fontsize='small', xtick_fontweight='bold',
               title='Average Temperature'):## Make the fig and axis first
    # plot the time series with pandas
    if title is None:
        title = ts_f.name
    fig, ax = plt.subplots(figsize=figsize)
    ts_f.plot(ax=ax,title=title);
    ax.set_ylabel("Degrees")
    ## creating our tick locators and formatters
    ## for minor month ticks
    #loc_1months = mdates.MonthLocator()
    #fmt_months = mdates.DateFormatter("%b")
    ## for major year ticks
    ## create the locator to place ticks every 5 years.
    loc_year1= mdates.YearLocator(interval=5)
    fmt_year1 = mdates.DateFormatter("%Y")
    #format_b = "%y"
    #now.strftime(format_b)
    loc_year2= mdates.YearLocator()
    fmt_year2 = mdates.DateFormatter("%Y")
    #ax.axvline(ts_f, color='k', linestyle='-',label='%B %d')
    
    ## Change the font of the major ticks to stand out
    ax.set_xticks(ax.get_xticks())
    ax.set_xticklabels(ax.get_xticklabels(), 
                       fontsize=xtick_fontsize, 
                       fontweight=xtick_fontweight) 
    
    ## customize minor ticks
    ax.xaxis.set_minor_locator(loc_year2)
    ax.xaxis.set_minor_formatter(fmt_year2)
    ## customize major ticks
    ax.xaxis.set_major_locator(loc_year1)
    ax.xaxis.set_major_formatter(fmt_year1)
    ## Making major/minor gridlines visually distinct
    ax.grid(which='minor',axis='x',ls=":")
    ax.grid(which='major',axis='x',color='k')
    ## rotate the dates
    fig.autofmt_xdate(which='major',rotation=90,ha='center')
    return fig,ax
    ax.axvline('2010-12-20',color='forestgreen',lw=3, ls=':', label="max_prec, 51.6")
    ax.legend()
plot_dates(ts_f);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[449], line 49
#      47     ax.axvline('2010-12-20',color='forestgreen',lw=3, ls=':', label="max_prec, 51.6")
#      48     ax.legend()
# ---> 49 plot_dates(ts_f)
#
# Cell In[449], line 21, in plot_dates(ts_f, figsize, xtick_fontsize, xtick_fontweight, title)
#      14 ax.set_ylabel("Degrees")
#      15 ## creating our tick locators and formatters
#      16 ## for minor month ticks
#      17 #loc_1months = mdates.MonthLocator()
#      18 #fmt_months = mdates.DateFormatter("%b")
#      19 ## for major year ticks
#      20 ## create the locator to place ticks every 5 years.
# ---> 21 loc_year1= mdates.YearLocator(interval=5)
#      22 fmt_year1 = mdates.DateFormatter("%Y")
#      23 #format_b = "%y"
#      24 #now.strftime(format_b)
#
# TypeError: __init__() got an unexpected keyword argument 'interval'
